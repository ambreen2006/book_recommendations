# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import sqlalchemy as db

from functools import reduce

# %% [markdown]
# # Data

# %%
data_dir = '../Data'

# %%
engine = db.create_engine('sqlite:///../Data/books.db')

# %%
connection = engine.connect()

# %%
books_meta_df = pd.read_sql_table('books_meta_data', connection)

# %%
books_meta_df.head()
# Out:
#    book_id                                          genre  \
# 0     1553                      Fiction / Fantasy / Urban
# 1     2090               Fiction / Fantasy / Contemporary
# 2     2341                               Fiction / Horror
# 3     2549  Fiction / Mystery & Detective / Women Sleuths
# 4     2550               Fiction / Fantasy / Dark Fantasy
#
#                                          description  \
# 0  First time in trade paperback: the third novel...
# 1  Animator and vampire hunter Anita Blake is abo...
# 2  In the sixth adventure in the #1 New York Time...
# 3  The Anita Blake, Vampire Hunter backlist light...
# 4  Anita Blake is a vampire hunter. But when some...
#
#                     date_time
# 0  2020-07-18T17:29:50.879040
# 1  2020-07-18T17:29:51.297302
# 2  2020-07-18T17:29:51.793606
# 3  2020-07-18T17:29:52.290241
# 4  2020-07-18T17:29:52.724854

# %%
all_genres = set()

# %%
split_genres = books_meta_df.genre.str.split('/').map(set).values

# %%
def genres_union(a, b):
    b.update(a)
    return b

all_genres = reduce(genres_union, split_genres, set())

# %%
all_genres = set(map(str.strip, all_genres))

# %%
len(all_genres)
# Out:
# 232

# %%
def create_genre_table(books_meta_df):
    
    def extract_genres(s):
        return set(map(str.strip, set(s.split('/'))))

    books_genres_df = pd.DataFrame()

    for index in books_meta_df.index:
        genre_sub_set = extract_genres(books_meta_df.loc[index, 'genre'])
        genre_sub_dict = {key:1 for key in genre_sub_set}
        genre_sub_dict['book_id'] = books_meta_df.loc[index, 'book_id']
        books_genres_df = books_genres_df.append(genre_sub_dict, ignore_index=True)

    books_genres_df = books_genres_df.astype('Int64')
    books_genres_df.fillna(0, inplace=True)
    books_genres_df.set_index('book_id', inplace=True)
    return books_genres_df

# %%
books_genres_df = create_genre_table(books_meta_df)

# %%
sorted(books_genres_df.columns.values)
# Out:
# ['19th Century Young Adult Fiction',
#  'Action & Adventure',
#  'Action & Adventure Fiction',
#  'Adaptations Young Adult Fiction',
#  'Adolescence',
#  'Adoption Young Adult Fiction',
#  'Alien Contact',
#  'Alien Contact Fiction',
#  'Alternative History',
#  'Amateur Sleuth Fiction',
#  'Ancient World',
#  'Animals',
#  'Apocalyptic & Post-Apocalyptic',
#  'Apologetics Religion',
#  'Arthurian Fiction',
#  'Arthurian Young Adult Fiction',
#  'Bears Juvenile Fiction',
#  'Biography & Autobiography',
#  'Black Humor Fiction',
#  'Boarding School & Prep School',
#  'Business, Careers, Occupations Juvenile Fiction',
#  'Cats',
#  'Cats Juvenile Fiction',
#  'Christian',
#  'Christian Life',
#  'Christian Theology',
#  'Christianity',
#  'Class Differences Young Adult Fiction',
#  'Classics Fiction',
#  'Clean & Wholesome',
#  'Clean & Wholesome Fiction',
#  'Comics & Graphic Novels',
#  'Coming of Age Fiction',
#  'Contemporary',
#  'Contemporary Fiction',
#  'Contemporary Young Adult Fiction',
#  'Cozy',
#  'Crime',
#  'Crime Fiction',
#  'Cyberpunk Fiction',
#  'Dark Fantasy',
#  'Dark Fantasy Fiction',
#  'Dark Fantasy Young Adult Fiction',
#  'Dating & Sex',
#  'Dating & Sex Young Adult Fiction',
#  'Death & Dying Young Adult Fiction',
#  'Death, Grief, Bereavement',
#  'Domestic',
#  'Dragons & Mythical Creatures',
#  'Dragons & Mythical Creatures Fiction',
#  'Drama',
#  'Emotions & Feelings Young Adult Fiction',
#  'Environment',
#  'Epic',
#  'Epic Fiction',
#  'Epic Young Adult Fiction',
#  'Erotica',
#  'Espionage Fiction',
#  'Essays',
#  'Essays & Travelogues',
#  'Essays & Travelogues Travel',
#  'Essays Humor',
#  'Essays Language Arts & Disciplines',
#  'Essays Science',
#  'Essays Social Science',
#  'Essays Travel',
#  'Fairy Tales & Folklore',
#  'Fairy Tales, Folk Tales, Legends & Mythology Fiction',
#  'Family',
#  'Family & Relationships',
#  'Family Life',
#  'Fantasy',
#  'Fantasy & Magic',
#  'Fantasy & Magic Juvenile Fiction',
#  'Fantasy & Magic Young Adult Fiction',
#  'Fantasy Comics & Graphic Novels',
#  'Fiction',
#  'Form',
#  'Friendship',
#  'Friendship Fiction',
#  'Futuristic Fiction',
#  'General',
#  'General Fiction',
#  'General History',
#  'General Humor',
#  'General Juvenile Fiction',
#  'General Language Arts & Disciplines',
#  'General Literary Collections',
#  'General Music',
#  'General Religion',
#  'General Social Science',
#  'General Young Adult Fiction',
#  'Genres & Styles',
#  'Ghost Fiction',
#  'Girls & Women',
#  'Girls & Women Juvenile Fiction',
#  'Girls & Women Young Adult Fiction',
#  'Hard Science Fiction',
#  'Hard-Boiled Fiction',
#  'Heavy Metal Music',
#  'Historical',
#  'Historical Biography & Autobiography',
#  'Historical Fiction',
#  'History',
#  'History & Criticism',
#  'History & Criticism Music',
#  'Holidays',
#  'Holidays & Celebrations',
#  'Horror',
#  'Horror Fiction',
#  'Horror Young Adult Fiction',
#  'Humor',
#  'Humorous',
#  'Humorous Fiction',
#  'Humorous Stories',
#  'Humorous Stories Juvenile Fiction',
#  'Imagination & Play',
#  'Instruction & Study',
#  'International Mystery & Crime',
#  'International Mystery & Crime Fiction',
#  'Juvenile Fiction',
#  'LGBT',
#  'Legal',
#  'Legal Fiction',
#  'Legends, Myths, Fables',
#  'Lesbian Fiction',
#  'Linguistics',
#  'Literary',
#  'Literary Fiction',
#  'Literary Figures Literary Criticism',
#  'Literary Figures Social Science',
#  'Literature & the Arts Religion',
#  'Love & Romance',
#  'Love & Romance Juvenile Fiction',
#  'Marriage & Divorce Fiction',
#  'Media Tie-In Fiction',
#  'Media Tie-In Young Adult Fiction',
#  'Medical Fiction',
#  'Medieval',
#  'Men, Women & Relationships',
#  'Military',
#  'Military Fiction',
#  'Music',
#  'Music Music',
#  'Mysteries & Detective Stories',
#  'Mysteries & Detective Stories Juvenile Fiction',
#  'Mysteries & Detective Stories Young Adult Fiction',
#  'Mystery & Detective',
#  'Native American & Aboriginal Fiction',
#  'Natural History',
#  'Nature & the Natural World',
#  'New Experience',
#  'Occult & Supernatural',
#  'Occult & Supernatural Fiction',
#  'Orphans & Foster Homes Juvenile Fiction',
#  'Paranormal',
#  'Paranormal Fiction',
#  'Paranormal Young Adult Fiction',
#  'Paranormal, Occult & Supernatural Young Adult Fiction',
#  'Parents Juvenile Fiction',
#  'Parents Young Adult Fiction',
#  'Parodies Humor',
#  'People & Places',
#  'Personal Memoirs Humor',
#  'Police Procedural Fiction',
#  'Political Fiction',
#  'Popular Culture',
#  'Pregnancy',
#  'Prejudice & Racism',
#  'Private Investigators',
#  'Private Investigators Fiction',
#  'Psychological',
#  'Psychological Fiction',
#  'Regency',
#  'Religion',
#  'Religious',
#  'Religious Fiction',
#  'Rock Social Science',
#  'Romance',
#  'Romance Fiction',
#  'Romantic Fiction',
#  'Royalty',
#  'Sagas',
#  'Sagas Fiction',
#  'Satire',
#  'Satire Fiction',
#  'School & Education',
#  'Science Fiction',
#  'Self-Esteem & Self-Reliance',
#  'Shakespeare',
#  'Shifters',
#  'Short Stories (single author)',
#  'Short Stories (single author) Fiction',
#  'Short Stories Fiction',
#  'Siblings Juvenile Fiction',
#  'Siblings Young Adult Fiction',
#  'Small Town & Rural Fiction',
#  'Social Themes',
#  'Songwriting',
#  'Southern Fiction',
#  'Space Opera',
#  'Spiritual Growth Religion',
#  'Spirituality',
#  'Spirituality Self-Help',
#  'Sports',
#  'Supernatural',
#  'Supernatural Fiction',
#  'Suspense',
#  'Suspense Fiction',
#  'Technological',
#  'Thrillers',
#  'Thrillers & Suspense',
#  'Topic',
#  'Traditional',
#  'Travel Travel',
#  'United States',
#  'Urban',
#  'Urban Fiction',
#  "Valentine's Day Juvenile Fiction",
#  'Values & Virtues',
#  'Vampires',
#  'Vampires Fiction',
#  'Visionary & Metaphysical',
#  'War & Military',
#  'Wars & Conflicts (Other)',
#  'Westerns',
#  'Women',
#  'Women Sleuths',
#  'Women Sleuths Fiction',
#  'World Science',
#  'World War I Fiction',
#  'Young Adult Fiction']

# %%
books_genres_df
# Out:
#          Fantasy  Fiction  Urban  Contemporary  Horror  Mystery & Detective  \
# book_id
# 1553           1        1      1             0       0                    0
# 2090           1        1      0             1       0                    0
# 2341           0        1      0             0       1                    0
# 2549           0        1      0             0       0                    1
# 2550           1        1      0             0       0                    0
# ...          ...      ...    ...           ...     ...                  ...
# 1972           0        1      0             0       0                    0
# 2673           0        1      0             0       0                    0
# 2730           0        1      0             0       0                    0
# 2859           0        1      0             0       0                    0
# 5655           0        1      0             0       0                    0
#
#          Women Sleuths  Dark Fantasy  Paranormal  Romance  ...  \
# book_id                                                    ...
# 1553                 0             0           0        0  ...
# 2090                 0             0           0        0  ...
# 2341                 0             0           0        0  ...
# 2549                 1             0           0        0  ...
# 2550                 0             1           0        0  ...
# ...                ...           ...         ...      ...  ...
# 1972                 0             0           0        0  ...
# 2673                 0             0           0        0  ...
# 2730                 0             0           0        0  ...
# 2859                 0             0           0        0  ...
# 5655                 0             0           0        0  ...
#
#          Adaptations Young Adult Fiction  Black Humor Fiction  \
# book_id
# 1553                                   0                    0
# 2090                                   0                    0
# 2341                                   0                    0
# 2549                                   0                    0
# 2550                                   0                    0
# ...                                  ...                  ...
# 1972                                   0                    0
# 2673                                   0                    0
# 2730                                   0                    0
# 2859                                   0                    0
# 5655                                   0                    0
#
#          Clean & Wholesome Fiction  Cozy  Fantasy & Magic Young Adult Fiction  \
# book_id
# 1553                             0     0                                    0
# 2090                             0     0                                    0
# 2341                             0     0                                    0
# 2549                             0     0                                    0
# 2550                             0     0                                    0
# ...                            ...   ...                                  ...
# 1972                             0     0                                    0
# 2673                             0     0                                    0
# 2730                             0     0                                    0
# 2859                             0     0                                    0
# 5655                             0     0                                    0
#
#          Bears Juvenile Fiction  Values & Virtues  Alien Contact  \
# book_id
# 1553                          0                 0              0
# 2090                          0                 0              0
# 2341                          0                 0              0
# 2549                          0                 0              0
# 2550                          0                 0              0
# ...                         ...               ...            ...
# 1972                          0                 0              0
# 2673                          0                 0              0
# 2730                          0                 0              0
# 2859                          0                 0              0
# 5655                          0                 0              0
#
#          Cyberpunk Fiction  Technological
# book_id
# 1553                     0              0
# 2090                     0              0
# 2341                     0              0
# 2549                     0              0
# 2550                     0              0
# ...                    ...            ...
# 1972                     0              0
# 2673                     0              0
# 2730                     0              0
# 2859                     0              1
# 5655                     0              0
#
# [574 rows x 232 columns]

# %% [markdown]
# # Cosine Similarity

# %% [markdown]
# $
# \begin{align}
# Similarity(A, B) = \frac{A . B}{\|{A}\| \|{B}\|} = \frac{\sum_{i=1}^nA_iB_i}{\sqrt{\sum_{i=1}^n{A_i}^2}\sqrt{\sum_{i=1}^n{B_i}^2}}
# \end{align}
# $

# %%
def create_similarity_matrix(books_genres_df):
    
    def cosine_similarity(x, y):
        a_dot_b = x.mul(y).sum()
        x_squared = x.pow(2).sum()
        y_squared = y.pow(2).sum()
        similarity = a_dot_b/(np.sqrt(x_squared)*np.sqrt(y_squared))
        return similarity

    num_books = books_genres_df.shape[0]
    similarity_matrix = np.zeros((num_books, num_books))

    for i in range(0, num_books):
        for j in range(num_books):
            x = books_genres_df.iloc[i,:]
            y = books_genres_df.iloc[j,:]
            similarity = cosine_similarity(x, y)
            similarity_matrix[i, j] = similarity
            similarity_matrix[j, i] = similarity    

    return similarity_matrix

genre_similarity_matrix = create_similarity_matrix(books_genres_df)

# %%
genre_similarity_matrix
# Out:
# array([[1.        , 0.66666667, 0.40824829, ..., 0.25819889, 0.25819889,
#         0.25819889],
#        [0.66666667, 1.        , 0.40824829, ..., 0.25819889, 0.25819889,
#         0.25819889],
#        [0.40824829, 0.40824829, 1.        , ..., 0.31622777, 0.31622777,
#         0.31622777],
#        ...,
#        [0.25819889, 0.25819889, 0.31622777, ..., 1.        , 0.8       ,
#         1.        ],
#        [0.25819889, 0.25819889, 0.31622777, ..., 0.8       , 1.        ,
#         0.8       ],
#        [0.25819889, 0.25819889, 0.31622777, ..., 1.        , 0.8       ,
#         1.        ]])

# %%
genre_similarity_matrix_df = pd.DataFrame(genre_similarity_matrix, index=books_genres_df.index, columns=books_genres_df.index)

# %%
genre_similarity_matrix_df.head()
# Out:
# book_id      1553      2090      2341      2549      2550      3510      3874  \
# book_id
# 1553     1.000000  0.666667  0.408248  0.333333  0.666667  0.666667  0.666667
# 2090     0.666667  1.000000  0.408248  0.333333  0.666667  0.666667  0.666667
# 2341     0.408248  0.408248  1.000000  0.408248  0.408248  0.408248  0.408248
# 2549     0.333333  0.333333  0.408248  1.000000  0.333333  0.333333  0.333333
# 2550     0.666667  0.666667  0.408248  0.333333  1.000000  0.666667  0.666667
#
# book_id      3990      4425      4656  ...      3035      3431      3940  \
# book_id                                ...
# 1553     0.666667  0.666667  0.666667  ...  0.235702  0.235702  0.235702
# 2090     0.666667  0.666667  0.666667  ...  0.235702  0.235702  0.235702
# 2341     0.408248  0.408248  0.408248  ...  0.288675  0.288675  0.288675
# 2549     0.333333  0.333333  0.333333  ...  0.471405  0.471405  0.471405
# 2550     1.000000  0.666667  0.666667  ...  0.235702  0.235702  0.235702
#
# book_id      4802      4876      1972      2673      2730      2859      5655
# book_id
# 1553     0.235702  0.235702  0.258199  0.258199  0.258199  0.258199  0.258199
# 2090     0.235702  0.235702  0.258199  0.258199  0.258199  0.258199  0.258199
# 2341     0.288675  0.288675  0.316228  0.316228  0.316228  0.316228  0.316228
# 2549     0.471405  0.471405  0.258199  0.258199  0.258199  0.258199  0.258199
# 2550     0.235702  0.235702  0.258199  0.258199  0.258199  0.258199  0.258199
#
# [5 rows x 574 columns]

# %%
genre_similarity_matrix_df.to_csv(data_dir+'/genre_similarity_matrix_df.csv')
